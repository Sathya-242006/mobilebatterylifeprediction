# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathya-242006/mobilebatterylifeprediction/blob/main/mobile_batt_life_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PREDICTING MOBILE BATTERY LIFE USING REGRESSION MODEL

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
data = {
    "ScreenOnTime": [3, 4, 5, 6, 2, 7, 3, 5, 4, 6],
    "AppUsage": [2, 3, 4, 5, 1, 6, 2, 4, 3, 5],
    "ChargingCycles": [20, 25, 30, 35, 15, 40, 18, 28, 22, 33],
    "BatteryHealth": [90, 88, 85, 80, 95, 75, 92, 87, 89, 82],
    "BatteryLife": [20, 18, 16, 14, 24, 12, 21, 17, 19, 15]
}
df = pd.DataFrame(data)
X = df[["ScreenOnTime", "AppUsage", "ChargingCycles", "BatteryHealth"]]
y = df["BatteryLife"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
pred = model.predict(X_test)
print("Mean Squared Error:", mean_squared_error(y_test, pred))
print("R2 Score:", r2_score(y_test, pred))
plt.scatter(y_test, pred, color="purple")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="red")
plt.xlabel("Actual Battery Life (hours)")
plt.ylabel("Predicted Battery Life (hours)")
plt.title("Actual vs Predicted Mobile Battery Life")
plt.show()
# Out:
# Mean Squared Error: 0.4843749999999995
# R2 Score: 0.9493095930232559
